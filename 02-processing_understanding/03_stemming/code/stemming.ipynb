# %% [markdown]
# # Stemming
#
# El paquete `nltk` tiene multiples formas de implementar *stemmers*. Estos *stemmers* son implementados en el módulo stem, el cual es heredero de la *interface* `StemmerI` en el módulo `nltk.ste.api`. Se puede crear un *stemmer* propio utilizando esta clase (técnicamente una interface) como clase base. Uno de los *stemmer* más populares es el [__Stemmer de Porter__](https://tartarus.org/martin/PorterStemmer/), el cual esta basado en el algoritmo de Dr. Martin Porte. Originalmente el algoritmo dice que tiene un total de cinco diferentes fases y su propio conjunto de reglas. También existe el algoritmo `Porter2`.

# %% [markdown]
# ## PorterStemmer
#
# El stemmer de Porter es un conjunto de reglas que quitan los sufijos comunes de los extremos de las palabras, cada una de estas reglas se aplica tras otra y produce nuestras palabras con un _stemmed_ de Porter. Es un _stemmer_ simple y muy rápido.

# %%
words = (
    ["eating",
    "eats",
    "eaten",
    "writing",
    "writes",
    "programming",
    "programs",
    "history",
    "finally",
    "finalized"]
)

# %%
from nltk.stem import PorterStemmer
stemming = PorterStemmer()

# %%
for word in words:
    print(word+" ----> "+stemming.stem(word))
# Out:
# eating ----> eat
# eats ----> eat
# eaten ----> eaten
# writing ----> write
# writes ----> write
# programming ----> program
# programs ----> program
# history ----> histori
# finally ----> final
# finalized ----> final

# %% [markdown]
# ## RegexpStemmer
#
# NLTK tiene una clase con la cual se puede implementar fácilmente un algoritmo de stemming, básicamente toma una expresión regular y remueve los prefijos y sufijos que concuerdan con la expresión.

# %%
from nltk.stem import RegexpStemmer

# %%
regex_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
print(regex_stemmer.stem('eating'))
# Out:
# eat

# %%
print(regex_stemmer.stem('ingeating'))
# Out:
# ingeat

# %% [markdown]
# ## LancasterStemmer
#
# El __Lancaster stemmer__ contiene un conjunto más amplio de reglas y en lugar de aplicar cada regla una tras otra, seguirá iterando a través de la lista de reglas y encontrará una regla que coincida con la condición actual, que luego eliminará o reemplazará la terminación de la palabra. Las iteraciones se detendrán una vez que no se puedan aplicar más reglas a la palabra o si la palabra comienza con una vocal y solo quedan dos caracteres o si la palabra comienza con una consonante y quedan tres caracteres. El stemmer de Lancaster es mucho más agresivo, a veces esto es algo bueno, a veces no.

# %%
from nltk.stem import LancasterStemmer

lancaster_stemmer = LancasterStemmer()

# %%
print(lancaster_stemmer.stem('lying'))
# Out:
# lying

# %%
print(lancaster_stemmer.stem('strange'))
# Out:
# strange

# %% [markdown]
# # Snowball Stemmer

# %%
from nltk.stem import SnowballStemmer

snowballsstemmer = SnowballStemmer("german")

# %%
print('Supported Languages:', SnowballStemmer.languages)
# Out:
# Supported Languages: ('arabic', 'danish', 'dutch', 'english', 'finnish', 'french', 'german', 'hungarian', 'italian', 'norwegian', 'porter', 'portuguese', 'romanian', 'russian', 'spanish', 'swedish')

# %%
# stemming on German words
# autobahnen -> cars
# autobahn -> car
snowballsstemmer.stem('autobahnen')
# Out:
# 'autobahn'

# %%
# springen -> jumping
# spring -> jump
snowballsstemmer.stem('springen')
# Out:
# 'spring'

# %%
for word in words:
    print(word+" ----> "+snowballsstemmer.stem(word))
# Out:
# eating ----> eating
# eats ----> eat
# eaten ----> eat
# writing ----> writing
# writes ----> writ
# programming ----> programming
# programs ----> program
# history ----> history
# finally ----> finally
# finalized ----> finalized
